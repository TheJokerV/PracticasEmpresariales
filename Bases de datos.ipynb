# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

pd.set_option('display.max_columns', None)

# %%
base = pd.read_excel('TablaDeDatos.xlsx', sheet_name = 'ESTUDIANTES')
estudiantes = pd.read_excel('ESTUDIANTES.xlsx')

# %% [markdown]
# <h1>DATOS EN CRUDO</h1>

# %%
base.head()
# Out:
#    AÑOINGRESO PERIODO_INGRESO       PERIODO_EGRESO DOCUMENTO     CÓDIGO  \
# 0        1997      1997-01-01  2013-01-01 00:00:00  71977148  971008101
# 1        1998      1998-02-01  2006-01-01 00:00:00  43621143  982056104
# 2        1999      1999-01-01            [NINGUNO]  28177911  991020214
# 3        2000      2000-01-01  2006-01-01 00:00:00  18009899  201010211
# 4        2001      2001-01-01  2015-01-01 00:00:00  19599564  211050106
#
#                              NOMBRE             PROGRAMA  NUM_MATRICULAS  \
# 0  CORDOBA DE LA ROSA JAVIER ANDRES        LIC. TEOLOGÍA              10
# 1       CATAÑO OCAMPO VIVIANA MARÍA  LIC. BÁS. NATURALES               1
# 2            CUBIDES GERENA BIVIANA   CONTADURÍA PÚBLICA               2
# 3      JAMES CUADRADO JOELL ELIECER     TEC. EMPRESARIAL               1
# 4        DIAZ MORENO ADOLFO ENRIQUE        LIC. TEOLOGÍA               5
#
#    CREDITOS_PENSUM  CREDITOS. APROB.  CREDITOS. REPROB.  MATERIASREPROBADAS  \
# ...

# %%
estudiantes.dtypes
# Out:
# AGNO_INGRESO                      int64
# FECHA_INGRESO            datetime64[ns]
# FECHA_EGRESO             datetime64[ns]
# DOCUMENTO                        object
# COD_ESTUDIANTIL                   int64
# NOMBRE                           object
# PROGRAMA                         object
# NUM_MATRICULAS                    int64
# CREDITOS_PENSUM                   int64
# CREDITOS_APROBADOS              float64
# CREDITOS_REPROBADOS               int64
# MATERIAS_REPROBADAS               int64
# MATERIAS_CANCELADAS               int64
# FECHA_NACIMIENTO         datetime64[ns]
# GENERO                           object
# ESTADO_CIVIL                     object
# RELIGION                         object
# MUNICIPIO_PROCEDENCIA            object
# DEPTO_PROCEDENCIA                object
# PAIS_PROCEDENCIA                 object
# ESTRATO                          object
# TRABAJO                          object
# TIPO_TRABAJO                     object
# ...

# %%
estudiantes[(estudiantes.PROGRAMA == 'LIC. TEOLOGÍA') & (estudiantes.ESTADO == 'GRADUADO')]
# Out:
#       AGNO_INGRESO FECHA_INGRESO FECHA_EGRESO   DOCUMENTO  COD_ESTUDIANTIL  \
# 0             1997    1997-01-01   2013-01-01    71977148        971008101
# 4             2001    2001-01-01   2015-01-01    19599564        211050106
# 6             2002    2002-01-01   2022-01-01    72251361        221022106
# 11            2003    2003-01-01   2007-02-01    79835203        231034106
# 16            2003    2003-01-01   2014-02-01    11807413        231052106
# ...            ...           ...          ...         ...              ...
# 2354          2018    2018-01-01   2022-02-01    87717648      20181070506
# 2370          2018    2018-01-01   2022-02-01  1005303309      20181078706
# 2373          2018    2018-01-01   2022-02-01      767769      20181079906
# 2376          2018    2018-01-01   2022-02-01  1047438212      20181081206
# 2383          2018    2018-01-01   2022-02-01  1044433208      20171055206
#
# ...

# %%
estudiantes[estudiantes.ESTADO == 'GRADUADO']
# Out:
#       AGNO_INGRESO FECHA_INGRESO FECHA_EGRESO   DOCUMENTO  COD_ESTUDIANTIL  \
# 0             1997    1997-01-01   2013-01-01    71977148        971008101
# 1             1998    1998-02-01   2006-01-01    43621143        982056104
# 3             2000    2000-01-01   2006-01-01    18009899        201010211
# 4             2001    2001-01-01   2015-01-01    19599564        211050106
# 5             2001    2001-01-01   2006-01-01    80207359        211016214
# ...            ...           ...          ...         ...              ...
# 3742          2022    2022-01-01   2022-02-01    36067992      20221030355
# 3748          2022    2022-01-01   2022-02-01  1082958659      20221031553
# 3776          2022    2022-01-01   2022-02-01  1117541744      20221036555
# 3780          2022    2022-01-01   2022-02-01  1057584412      20221037955
# 3959          2022    2022-01-01   2022-02-01  1127061859      20221040055
#
# ...
