# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
base = pd.read_excel('base de datos objeto de estudio.xlsx')
egresados = pd.read_excel('Infromación de egresados.xls')
sistemasGeneral = base[base.NOMBREPROGRAMA == 'INGENIERÍA DE SISTEMAS']
sistemasGraduados = pd.merge(base[(base.NOMBREPROGRAMA == 'INGENIERÍA DE SISTEMAS') & (base.GRADUADO == 'SÍ')], egresados, how='inner', left_on='CODIGOESTUDIANTIL', right_on='CODIGO')

# %% [markdown]
# #DATOS ESTUDIANTES.

# %%
base.head()
# Out:
#    AÑOINGRESO PERIODOINGRESO DOCUMENTO  CODIGOESTUDIANTIL  \
# 0        1996         1996-1  43546529          961021102
# 1        1997         1997-1  79794215          971052101
# 2        1997         1997-1  79794215          971052101
# 3        1997         1997-1  71977148          971008101
# 4        1997         1997-1  71777325          971004102
#
#                    NOMBREESTUDIANTE            NOMBREPROGRAMA  NUM_MATRICULAS  \
# 0   CARVAJAL CASTAÑO MARTHA CECILIA    LICENCIATURA EN MÚSICA               1
# 1       CARVAJAL BELLO BORIS ARGOTY  LICENCIATURA EN TEOLOGÍA               1
# 2       CARVAJAL BELLO BORIS ARGOTY  LICENCIATURA EN TEOLOGÍA               1
# 3  CORDOBA DE LA ROSA JAVIER ANDRES  LICENCIATURA EN TEOLOGÍA               2
# 4           MOLINA RUIZ LUIS ANDRÉS    LICENCIATURA EN MÚSICA               1
#
#   ULTIMOPERIODOMATRICULADO  SALDO_FINANZAS  CR_PENSUM  ...  NUMEROHERMANOS  \
# 0                   2016-1             0.0        177  ...             NaN
# 1                   2006-2             0.0        173  ...             NaN
# 2                   2006-2             0.0        189  ...             NaN
# 3                   2008-1       5305429.0        173  ...             NaN
# 4                   2010-1             0.0        177  ...             NaN
#
#    NUMEROPERSONASACARGO  TRABAJARAESTEPERIODO  TIPOTRABAJO  ROANGOINGRESOS  \
# 0                     0                    NO    [NINGUNO]       [NINGUNO]
# 1                     0                    NO          NaN             NaN
# 2                     0                    NO          NaN             NaN
# 3                     0                    NO          NaN             NaN
# 4                     0                    NO          NaN             NaN
#
#    DURACIONTRABAJO  ESRESIDENTE             TIPOESTADIAEXTERNA  retirado  \
# 0        [NINGUNO]           NO  ESTUDIANTE VIVE CON ACUDIENTE        NO
# 1              NaN           NO                            NaN        NO
# 2              NaN           NO                            NaN        NO
# 3              NaN           NO                            NaN        NO
# 4              NaN           NO                            NaN        NO
#
#   GRADUADO
# 0       NO
# 1       NO
# 2       SÍ
# 3       SÍ
# 4       NO
#
# [5 rows x 65 columns]

# %% [markdown]
# #DATOS DE INGENIERIA DE SISTEMAS.

# %%
sistemasGeneral.head()
# Out:
#       AÑOINGRESO PERIODOINGRESO    DOCUMENTO  CODIGOESTUDIANTIL  \
# 4124        2013         2013-1  95120702667        20131031190
# 4129        2013         2013-1   1128278810        20131058990
# 4131        2013         2013-1   1128279180        20131027090
# 4159        2013         2013-1   1110503190        20131004090
# 4164        2013         2013-1   1101387061        20131015790
#
#                       NOMBREESTUDIANTE          NOMBREPROGRAMA  \
# 4124            ARCE MOSQUERA ANDERSON  INGENIERÍA DE SISTEMAS
# 4129      ARRIETA FERRER EDWIN ALBERTO  INGENIERÍA DE SISTEMAS
# 4131         ARTEAGA MURILLLO CAROLINA  INGENIERÍA DE SISTEMAS
# 4159  BONILLA ESPINOSA CRISTHIAN ARIEL  INGENIERÍA DE SISTEMAS
# 4164      CÁCERES OLIVARES SARA NAYDUT  INGENIERÍA DE SISTEMAS
#
#       NUM_MATRICULAS ULTIMOPERIODOMATRICULADO  SALDO_FINANZAS  CR_PENSUM  ...  \
# 4124               1                   2013-1    1.342454e+06        161  ...
# 4129               6                   2016-1   -1.000000e-04        161  ...
# 4131              10                   2017-2    0.000000e+00        161  ...
# 4159               5                   2015-1   -1.060010e+04        161  ...
# 4164               5                   2015-1   -2.554000e+03        161  ...
#
#       NUMEROHERMANOS  NUMEROPERSONASACARGO  TRABAJARAESTEPERIODO  \
# 4124             NaN                     0                    SÍ
# 4129             NaN                     0                    SÍ
# 4131             NaN                     0                    NO
# 4159             NaN                     0                    NO
# 4164             NaN                     0                    SÍ
#
#           TIPOTRABAJO       ROANGOINGRESOS        DURACIONTRABAJO  \
# 4124     MEDIO TIEMPO   ENTRE 0 - 1 MÍNIMO  ENTRE 6 MESES - 1 AÑO
# 4129  TIEMPO COMPLETO  ENTRE 2 - 3 MÍNIMOS           MÁS DE 1 AÑO
# 4131        [NINGUNO]            [NINGUNO]              [NINGUNO]
# 4159        [NINGUNO]            [NINGUNO]              [NINGUNO]
# 4164  TIEMPO COMPLETO  ENTRE 1 - 2 MÍNIMOS        ENTRE 0-6 MESES
#
#       ESRESIDENTE             TIPOESTADIAEXTERNA  retirado GRADUADO
# 4124           NO                            NaN        SÍ       NO
# 4129           NO    ESTUDIANTE ES JEFE DE HOGAR        NO       SÍ
# 4131           NO  ESTUDIANTE VIVE CON ACUDIENTE        NO       SÍ
# 4159           NO  ESTUDIANTE VIVE CON ACUDIENTE        NO       SÍ
# 4164           SÍ                     EN TRÁMITE        NO       SÍ
#
# [5 rows x 65 columns]

# %% [markdown]
# #DATOS DE EGRESADOS DE INGENIERIA DE SISTEMAS.

# %%
egresados.head()
# Out:
#    AGNO       CODIGO FECHA EGRESO
# 0  2015  20131015790   2015-08-01
# 1  2015  20131024290   2015-08-01
# 2  2015  20131055090   2015-08-01
# 3  2015  20131024990   2015-11-28
# 4  2015  20131044890   2015-08-01

# %%
sistemasGraduados.head()
# Out:
#    AÑOINGRESO PERIODOINGRESO   DOCUMENTO  CODIGOESTUDIANTIL  \
# 0        2013         2013-1  1128278810        20131058990
# 1        2013         2013-1  1128279180        20131027090
# 2        2013         2013-1  1110503190        20131004090
# 3        2013         2013-1  1101387061        20131015790
# 4        2013         2013-1  1152436157        20131024290
#
#                    NOMBREESTUDIANTE          NOMBREPROGRAMA  NUM_MATRICULAS  \
# 0      ARRIETA FERRER EDWIN ALBERTO  INGENIERÍA DE SISTEMAS               6
# 1         ARTEAGA MURILLLO CAROLINA  INGENIERÍA DE SISTEMAS              10
# 2  BONILLA ESPINOSA CRISTHIAN ARIEL  INGENIERÍA DE SISTEMAS               5
# 3      CÁCERES OLIVARES SARA NAYDUT  INGENIERÍA DE SISTEMAS               5
# 4          DAZA ACEVEDO LUIS CARLOS  INGENIERÍA DE SISTEMAS               5
#
#   ULTIMOPERIODOMATRICULADO  SALDO_FINANZAS  CR_PENSUM  ...      TIPOTRABAJO  \
# 0                   2016-1         -0.0001        161  ...  TIEMPO COMPLETO
# 1                   2017-2          0.0000        161  ...        [NINGUNO]
# 2                   2015-1     -10600.0972        161  ...        [NINGUNO]
# 3                   2015-1      -2554.0000        161  ...  TIEMPO COMPLETO
# 4                   2015-1          0.0000        161  ...  TIEMPO COMPLETO
#
#         ROANGOINGRESOS        DURACIONTRABAJO  ESRESIDENTE  \
# 0  ENTRE 2 - 3 MÍNIMOS           MÁS DE 1 AÑO           NO
# 1            [NINGUNO]              [NINGUNO]           NO
# 2            [NINGUNO]              [NINGUNO]           NO
# 3  ENTRE 1 - 2 MÍNIMOS        ENTRE 0-6 MESES           SÍ
# 4  ENTRE 1 - 2 MÍNIMOS  ENTRE 6 MESES - 1 AÑO           NO
#
#               TIPOESTADIAEXTERNA  retirado  GRADUADO  AGNO       CODIGO  \
# 0    ESTUDIANTE ES JEFE DE HOGAR        NO        SÍ  2016  20131058990
# 1  ESTUDIANTE VIVE CON ACUDIENTE        NO        SÍ  2019  20131027090
# 2  ESTUDIANTE VIVE CON ACUDIENTE        NO        SÍ  2016  20131004090
# 3                     EN TRÁMITE        NO        SÍ  2015  20131015790
# 4    ESTUDIANTE ES JEFE DE HOGAR        NO        SÍ  2015  20131024290
#
#   FECHA EGRESO
# 0   2016-07-23
# 1   2019-07-28
# 2   2016-03-07
# 3   2015-08-01
# 4   2015-08-01
#
# [5 rows x 68 columns]
